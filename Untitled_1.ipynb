# %%
from PIL import Image
import numpy as np
import rasterio
from rasterio.plot import show

# %%
with rasterio.open('NMC.tif') as image:
    image_array = image.read()

# %%
show(image_array)
# Out:
# <AxesSubplot: >
